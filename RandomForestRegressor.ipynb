# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("housing.csv")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
#        population  households  median_income  median_house_value  \
# 0             322         126         8.3252              452600
# 1            2401        1138         8.3014              358500
# 2             496         177         7.2574              352100
# 3             558         219         5.6431              341300
# 4             565         259         3.8462              342200
# ...           ...         ...            ...                 ...
# 20635         845         330         1.5603               78100
# 20636         356         114         2.5568               77100
# 20637        1007         433         1.7000               92300
# 20638         741         349         1.8672               84700
# 20639        1387         530         2.3886               89400
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  int64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  int64
#  6   households          20640 non-null  int64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  int64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  int64
#  3   total_rooms         20433 non-null  int64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  int64
#  6   households          20433 non-null  int64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  int64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split
X = data.drop(['median_house_value'], axis=1)
y = data['median_house_value']

# %%
X
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
#        population  households  median_income ocean_proximity
# 0             322         126         8.3252        NEAR BAY
# 1            2401        1138         8.3014        NEAR BAY
# 2             496         177         7.2574        NEAR BAY
# 3             558         219         5.6431        NEAR BAY
# 4             565         259         3.8462        NEAR BAY
# ...           ...         ...            ...             ...
# 20635         845         330         1.5603          INLAND
# 20636         356         114         2.5568          INLAND
# 20637        1007         433         1.7000          INLAND
# 20638         741         349         1.8672          INLAND
# 20639        1387         530         2.3886          INLAND
#
# [20433 rows x 9 columns]

# %%
y.head()
# Out:
# 0    452600
# 1    358500
# 2    352100
# 3    341300
# 4    342200
# Name: median_house_value, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y , test_size = 0.2)

# %%
train_data = X_train.join(y_train)
test_data = X_test.join(y_test)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 11796    -121.30     39.00                  16         3155           541.0
# 14787    -117.13     32.58                  27         2511           615.0
# 20429    -118.84     34.22                  11         3170           420.0
# 15462    -117.22     33.17                   6         1487           362.0
# 1172     -121.62     39.50                  18         2105           416.0
# ...          ...       ...                 ...          ...             ...
# 6175     -117.93     34.08                  36         1597           285.0
# 13688    -117.20     34.15                  18         1859           251.0
# 13127    -121.31     38.28                  16         1708           391.0
# 15592    -116.32     33.28                  19         1791           367.0
# 19222    -122.70     38.46                  29         2891           459.0
#
#        population  households  median_income ocean_proximity  \
# 11796        1630         540         4.0282          INLAND
# 14787        1427         576         3.1645      NEAR OCEAN
# 20429        1418         432         7.5118       <1H OCEAN
# 15462         810         322         3.6250       <1H OCEAN
# 1172          974         385         1.6346          INLAND
# ...           ...         ...            ...             ...
# 6175          901         272         4.3947       <1H OCEAN
# 13688         747         256         7.7320          INLAND
# 13127         687         378         1.9485          INLAND
# 15592         327         185         3.3625          INLAND
# 19222        1012         441         5.0415       <1H OCEAN
#
#        median_house_value
# 11796              126400
# 14787              156000
# 20429              361900
# 15462              135700
# 1172                63300
# ...                   ...
# 6175               197000
# 13688              173200
# 13127              155400
# 15592              100000
# 19222              240200
#
# [16346 rows x 10 columns]

# %%
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 11972    -117.43     34.01                  34         2101           426.0
# 15597    -116.45     32.65                  22         2680           643.0
# 15125    -116.86     32.87                  17         5799           921.0
# 8807     -118.38     33.75                  23         8277          1290.0
# 19110    -122.64     38.23                  52         1075           249.0
# ...          ...       ...                 ...          ...             ...
# 12537    -121.51     38.55                  46         1485           278.0
# 5609     -118.27     33.79                  31         1535           369.0
# 4588     -118.27     34.05                  52         1292           864.0
# 15874    -122.40     37.75                  52         1182           307.0
# 17453    -120.47     34.71                  21         2535           383.0
#
#        population  households  median_income ocean_proximity  \
# 11972        1150         377         3.0909          INLAND
# 15597        1644         516         2.1949          INLAND
# 15125        2630         843         5.0524       <1H OCEAN
# 8807         3176        1159         7.6986      NEAR OCEAN
# 19110         519         210         3.0769       <1H OCEAN
# ...           ...         ...            ...             ...
# 12537         531         291         2.7885          INLAND
# 5609         1291         340         2.9375       <1H OCEAN
# 4588         2081         724         0.9563       <1H OCEAN
# 15874        1029         306         2.0577        NEAR BAY
# 17453        1012         368         5.6177      NEAR OCEAN
#
#        median_house_value
# 11972               98300
# 15597              127100
# 15125              285400
# 8807               500001
# 19110              230900
# ...                   ...
# 12537              137200
# 5609               174000
# 4588               275000
# 15874              214600
# 17453              183800
#
# [4087 rows x 10 columns]

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     7262
# INLAND        5180
# NEAR OCEAN    2093
# NEAR BAY      1807
# ISLAND           4
# Name: count, dtype: int64

# %%
test_data.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     1772
# INLAND        1316
# NEAR OCEAN     535
# NEAR BAY       463
# ISLAND           1
# Name: count, dtype: int64

# %%
one_hot_encoded = pd.get_dummies(train_data.ocean_proximity)
one_hot_encoded = one_hot_encoded.astype(int)

# %%
train_data = train_data.join(one_hot_encoded).drop(['ocean_proximity'],axis=1)

# %%
train_data.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 11796    -121.30     39.00                  16         3155           541.0
# 14787    -117.13     32.58                  27         2511           615.0
# 20429    -118.84     34.22                  11         3170           420.0
# 15462    -117.22     33.17                   6         1487           362.0
# 1172     -121.62     39.50                  18         2105           416.0
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 11796        1630         540         4.0282              126400          0
# 14787        1427         576         3.1645              156000          0
# 20429        1418         432         7.5118              361900          1
# 15462         810         322         3.6250              135700          1
# 1172          974         385         1.6346               63300          0
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 11796       1       0         0           0
# 14787       0       0         0           1
# 20429       0       0         0           0
# 15462       0       0         0           0
# 1172        1       0         0           0

# %%
one_hot_encoded = pd.get_dummies(test_data.ocean_proximity)
one_hot_encoded = one_hot_encoded.astype(int)

# %%
test_data = test_data.join(one_hot_encoded).drop(['ocean_proximity'],axis=1)

# %%
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 11972    -117.43     34.01                  34         2101           426.0
# 15597    -116.45     32.65                  22         2680           643.0
# 15125    -116.86     32.87                  17         5799           921.0
# 8807     -118.38     33.75                  23         8277          1290.0
# 19110    -122.64     38.23                  52         1075           249.0
# ...          ...       ...                 ...          ...             ...
# 12537    -121.51     38.55                  46         1485           278.0
# 5609     -118.27     33.79                  31         1535           369.0
# 4588     -118.27     34.05                  52         1292           864.0
# 15874    -122.40     37.75                  52         1182           307.0
# 17453    -120.47     34.71                  21         2535           383.0
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 11972        1150         377         3.0909               98300          0
# 15597        1644         516         2.1949              127100          0
# 15125        2630         843         5.0524              285400          1
# 8807         3176        1159         7.6986              500001          0
# 19110         519         210         3.0769              230900          1
# ...           ...         ...            ...                 ...        ...
# 12537         531         291         2.7885              137200          0
# 5609         1291         340         2.9375              174000          1
# 4588         2081         724         0.9563              275000          1
# 15874        1029         306         2.0577              214600          0
# 17453        1012         368         5.6177              183800          0
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 11972       1       0         0           0
# 15597       1       0         0           0
# 15125       0       0         0           0
# 8807        0       0         0           1
# 19110       0       0         0           0
# ...       ...     ...       ...         ...
# 12537       1       0         0           0
# 5609        0       0         0           0
# 4588        0       0         0           0
# 15874       0       0         1           0
# 17453       0       0         0           1
#
# [4087 rows x 14 columns]

# %%
X_test = test_data.drop(['median_house_value'], axis=1)
y_test = test_data['median_house_value']

# %%
train_data.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.925647           -0.109241     0.042297
# latitude            -0.925647  1.000000            0.011607    -0.034497
# housing_median_age  -0.109241  0.011607            1.000000    -0.361319
# total_rooms          0.042297 -0.034497           -0.361319     1.000000
# total_bedrooms       0.063594 -0.062073           -0.319636     0.930705
# population           0.095038 -0.104356           -0.290638     0.851419
# households           0.050326 -0.066407           -0.301758     0.918204
# median_income       -0.012705 -0.080523           -0.118324     0.193329
# median_house_value  -0.042852 -0.145153            0.110262     0.132558
# <1H OCEAN            0.323250 -0.448649            0.047549    -0.006982
# INLAND              -0.055309  0.348903           -0.237154     0.024900
# ISLAND               0.009429 -0.016599            0.014197    -0.009146
# NEAR BAY            -0.474456  0.359413            0.251376    -0.018820
# NEAR OCEAN           0.041131 -0.155170            0.022948    -0.006199
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.063594    0.095038    0.050326      -0.012705
# latitude                 -0.062073   -0.104356   -0.066407      -0.080523
# housing_median_age       -0.319636   -0.290638   -0.301758      -0.118324
# total_rooms               0.930705    0.851419    0.918204       0.193329
# total_bedrooms            1.000000    0.874573    0.979574      -0.014124
# population                0.874573    1.000000    0.904232      -0.001848
# households                0.979574    0.904232    1.000000       0.006689
# median_income            -0.014124   -0.001848    0.006689       1.000000
# median_house_value        0.047567   -0.027787    0.062578       0.686452
# <1H OCEAN                 0.014335    0.070910    0.037443       0.171024
# INLAND                   -0.006907   -0.022315   -0.038373      -0.234872
# ISLAND                   -0.005997   -0.011975   -0.010798      -0.009522
# NEAR BAY                 -0.012891   -0.056345   -0.004590       0.051994
# NEAR OCEAN                0.000677   -0.020939    0.002564       0.024373
#
#                     median_house_value  <1H OCEAN    INLAND    ISLAND  \
# longitude                    -0.042852   0.323250 -0.055309  0.009429
# latitude                     -0.145153  -0.448649  0.348903 -0.016599
# housing_median_age            0.110262   0.047549 -0.237154  0.014197
# total_rooms                   0.132558  -0.006982  0.024900 -0.009146
# total_bedrooms                0.047567   0.014335 -0.006907 -0.005997
# population                   -0.027787   0.070910 -0.022315 -0.011975
# households                    0.062578   0.037443 -0.038373 -0.010798
# median_income                 0.686452   0.171024 -0.234872 -0.009522
# median_house_value            1.000000   0.258450 -0.480437  0.022481
# <1H OCEAN                     0.258450   1.000000 -0.608984 -0.013988
# INLAND                       -0.480437  -0.608984  1.000000 -0.010656
# ISLAND                        0.022481  -0.013988 -0.010656  1.000000
# NEAR BAY                      0.156956  -0.315211 -0.240120 -0.005516
# NEAR OCEAN                    0.136301  -0.342627 -0.261004 -0.005995
#
#                     NEAR BAY  NEAR OCEAN
# longitude          -0.474456    0.041131
# latitude            0.359413   -0.155170
# housing_median_age  0.251376    0.022948
# total_rooms        -0.018820   -0.006199
# total_bedrooms     -0.012891    0.000677
# population         -0.056345   -0.020939
# households         -0.004590    0.002564
# median_income       0.051994    0.024373
# median_house_value  0.156956    0.136301
# <1H OCEAN          -0.315211   -0.342627
# INLAND             -0.240120   -0.261004
# ISLAND             -0.005516   -0.005995
# NEAR BAY            1.000000   -0.135096
# NEAR OCEAN         -0.135096    1.000000

# %%
plt.figure(figsize = (15,8))
sns.heatmap(train_data.corr(), annot = True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x="latitude", y="longitude", data= train_data, hue = "median_house_value",palette = "coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
train_data['bedroom_ratio'] = train_data['total_bedrooms'] / train_data['total_rooms']
train_data['household_rooms'] = train_data['total_rooms'] / train_data['households']

# %%
plt.figure(figsize = (15,8))
sns.heatmap(train_data.corr(), annot = True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 11796    -121.30     39.00                  16         3155           541.0
# 14787    -117.13     32.58                  27         2511           615.0
# 20429    -118.84     34.22                  11         3170           420.0
# 15462    -117.22     33.17                   6         1487           362.0
# 1172     -121.62     39.50                  18         2105           416.0
# ...          ...       ...                 ...          ...             ...
# 6175     -117.93     34.08                  36         1597           285.0
# 13688    -117.20     34.15                  18         1859           251.0
# 13127    -121.31     38.28                  16         1708           391.0
# 15592    -116.32     33.28                  19         1791           367.0
# 19222    -122.70     38.46                  29         2891           459.0
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 11796        1630         540         4.0282              126400          0
# 14787        1427         576         3.1645              156000          0
# 20429        1418         432         7.5118              361900          1
# 15462         810         322         3.6250              135700          1
# 1172          974         385         1.6346               63300          0
# ...           ...         ...            ...                 ...        ...
# 6175          901         272         4.3947              197000          1
# 13688         747         256         7.7320              173200          0
# 13127         687         378         1.9485              155400          0
# 15592         327         185         3.3625              100000          0
# 19222        1012         441         5.0415              240200          1
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 11796       1       0         0           0       0.171474         5.842593
# 14787       0       0         0           1       0.244922         4.359375
# 20429       0       0         0           0       0.132492         7.337963
# 15462       0       0         0           0       0.243443         4.618012
# 1172        1       0         0           0       0.197625         5.467532
# ...       ...     ...       ...         ...            ...              ...
# 6175        0       0         0           0       0.178460         5.871324
# 13688       1       0         0           0       0.135019         7.261719
# 13127       1       0         0           0       0.228923         4.518519
# 15592       1       0         0           0       0.204913         9.681081
# 19222       0       0         0           0       0.158769         6.555556
#
# [16346 rows x 16 columns]

# %%
X_train = train_data.drop(['median_house_value'], axis=1)
y_train = train_data['median_house_value']

# %%
test_data['bedroom_ratio'] = test_data['total_bedrooms'] / test_data['total_rooms']
test_data['household_rooms'] = test_data['total_rooms'] / test_data['households']

# %%
X_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 11796    -121.30     39.00                  16         3155           541.0
# 14787    -117.13     32.58                  27         2511           615.0
# 20429    -118.84     34.22                  11         3170           420.0
# 15462    -117.22     33.17                   6         1487           362.0
# 1172     -121.62     39.50                  18         2105           416.0
# ...          ...       ...                 ...          ...             ...
# 6175     -117.93     34.08                  36         1597           285.0
# 13688    -117.20     34.15                  18         1859           251.0
# 13127    -121.31     38.28                  16         1708           391.0
# 15592    -116.32     33.28                  19         1791           367.0
# 19222    -122.70     38.46                  29         2891           459.0
#
#        population  households  median_income  <1H OCEAN  INLAND  ISLAND  \
# 11796        1630         540         4.0282          0       1       0
# 14787        1427         576         3.1645          0       0       0
# 20429        1418         432         7.5118          1       0       0
# 15462         810         322         3.6250          1       0       0
# 1172          974         385         1.6346          0       1       0
# ...           ...         ...            ...        ...     ...     ...
# 6175          901         272         4.3947          1       0       0
# 13688         747         256         7.7320          0       1       0
# 13127         687         378         1.9485          0       1       0
# 15592         327         185         3.3625          0       1       0
# 19222        1012         441         5.0415          1       0       0
#
#        NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 11796         0           0       0.171474         5.842593
# 14787         0           1       0.244922         4.359375
# 20429         0           0       0.132492         7.337963
# 15462         0           0       0.243443         4.618012
# 1172          0           0       0.197625         5.467532
# ...         ...         ...            ...              ...
# 6175          0           0       0.178460         5.871324
# 13688         0           0       0.135019         7.261719
# 13127         0           0       0.228923         4.518519
# 15592         0           0       0.204913         9.681081
# 19222         0           0       0.158769         6.555556
#
# [16346 rows x 15 columns]

# %%
y_train
# Out:
# 11796    126400
# 14787    156000
# 20429    361900
# 15462    135700
# 1172      63300
#           ...
# 6175     197000
# 13688    173200
# 13127    155400
# 15592    100000
# 19222    240200
# Name: median_house_value, Length: 16346, dtype: int64

# %%
X_test = test_data.drop(['median_house_value'], axis=1)
y_test = test_data['median_house_value']
X_test
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 11972    -117.43     34.01                  34         2101           426.0
# 15597    -116.45     32.65                  22         2680           643.0
# 15125    -116.86     32.87                  17         5799           921.0
# 8807     -118.38     33.75                  23         8277          1290.0
# 19110    -122.64     38.23                  52         1075           249.0
# ...          ...       ...                 ...          ...             ...
# 12537    -121.51     38.55                  46         1485           278.0
# 5609     -118.27     33.79                  31         1535           369.0
# 4588     -118.27     34.05                  52         1292           864.0
# 15874    -122.40     37.75                  52         1182           307.0
# 17453    -120.47     34.71                  21         2535           383.0
#
#        population  households  median_income  <1H OCEAN  INLAND  ISLAND  \
# 11972        1150         377         3.0909          0       1       0
# 15597        1644         516         2.1949          0       1       0
# 15125        2630         843         5.0524          1       0       0
# 8807         3176        1159         7.6986          0       0       0
# 19110         519         210         3.0769          1       0       0
# ...           ...         ...            ...        ...     ...     ...
# 12537         531         291         2.7885          0       1       0
# 5609         1291         340         2.9375          1       0       0
# 4588         2081         724         0.9563          1       0       0
# 15874        1029         306         2.0577          0       0       0
# 17453        1012         368         5.6177          0       0       0
#
#        NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 11972         0           0       0.202761         5.572944
# 15597         0           0       0.239925         5.193798
# 15125         0           0       0.158820         6.879004
# 8807          0           1       0.155854         7.141501
# 19110         0           0       0.231628         5.119048
# ...         ...         ...            ...              ...
# 12537         0           0       0.187205         5.103093
# 5609          0           0       0.240391         4.514706
# 4588          0           0       0.668731         1.784530
# 15874         1           0       0.259729         3.862745
# 17453         0           1       0.151085         6.888587
#
# [4087 rows x 15 columns]

# %%
from sklearn.ensemble import RandomForestRegressor
forest = RandomForestRegressor()
forest.fit(X_train,y_train)
forest.score(X_test,y_test)
# Out:
# 0.7981157317344753

# %%
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.ensemble import RandomForestRegressor

# Define the number of folds (k)
k = 5

# Shuffle the DataFrame rows
train_data = train_data.sample(frac=1).reset_index(drop=True)

# Get the features (X) and target variable (y) from the DataFrame
X = train_data.drop(columns=['median_house_value'])
y = train_data['median_house_value']

# Initialize the KFold object
kf = KFold(n_splits = k)

# Iterate over the folds
for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Performing model training and evaluation
    forest = RandomForestRegressor()
    forest.fit(X_train,y_train)
    print(forest.score(X_test,y_test))
# Out:
# 0.825465075238787
# 0.8017252407266557
# 0.819346762887402
# 0.8063688865139511
# 0.8093141296100468

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'n_estimators': [100, 200, 300],  # Number of trees in the forest
    'max_depth': [None, 5, 10],       # Maximum depth of each tree
    'min_samples_split': [2, 5, 10],  # Minimum number of samples required to split an internal node
    'min_samples_leaf': [1, 2, 4]     # Minimum number of samples required to be at a leaf node
}

# %%
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.ensemble import RandomForestRegressor

# Define the number of folds (k)
k = 5

# Shuffle the DataFrame rows
train_data = train_data.sample(frac=1).reset_index(drop=True)

# Get the features (X) and target variable (y) from the DataFrame
X = train_data.drop(columns=['median_house_value'])
y = train_data['median_house_value']

# Initialize the KFold object
kf = KFold(n_splits = k)

# %%
# Iterate over the folds
for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    grid_search = GridSearchCV(RandomForestRegressor(), param_grid, scoring='r2', cv=k)
    grid_search.fit(X_train, y_train)

    print("Best Parameters: ", grid_search.best_params_)
    print("Best Score: ", grid_search.best_score_)
# Out:
# Best Parameters:  {'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 300}
# Best Score:  0.8105368658502474
# Best Parameters:  {'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 300}
# Best Score:  0.8097222546532972

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import mean_squared_error
import numpy as np

# Assuming you have loaded and preprocessed your housing dataset into X and y variables

# Perform K-fold cross-validation
k = 5  # Number of folds for cross-validation
y_pred = cross_val_predict(forest, X_train, y_train, cv=k)

# Calculate the root mean squared error (RMSE) as an evaluation metric
rmse = np.sqrt(mean_squared_error(y_train , y_pred))
print("Root Mean Squared Error (RMSE):", rmse)

# You can also use the trained model to make predictions on new, unseen data
# Assuming you have loaded and preprocessed new data into X_new variable
random_rows = X_test[:10]
new_predictions = forest.predict(random_rows)

# Display the predicted prices on the new data
print(new_predictions)

# %%
import numpy as np
import pandas as pd

# Manually enter the sample data as a dictionary
sample_data = {
    'longitude': -121.30,
    'latitude': 38.69,
    'housing_median_age': 21.0,
    'total_rooms': 6575.0,
    'total_bedrooms': 1105.0,
    'population': 3358.0,
    'households': 1098.0,
    'median_income': 4.0739,
    '<1H OCEAN': 0,
    'INLAND': 1,
    'ISLAND': 0,
    'NEAR BAY': 0,
    'NEAR OCEAN': 0
}

# Convert the sample data into a DataFrame
sample_df = pd.DataFrame(sample_data, index=[0])

# Make predictions on the sample data using your trained model
predicted_price = forest.predict(sample_df)

# Display the predicted house value
print("Predicted House Value:", predicted_price)
# Out:
# Predicted House Value: [138520.]
